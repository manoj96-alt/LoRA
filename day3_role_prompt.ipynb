# %% [markdown]
# <a href="https://colab.research.google.com/github/manoj96-alt/LoRA/blob/main/day3_role_prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
from openai import OpenAI
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
print("AI Role Assistant\n")

role = input("Choose role (teacher / programmer / product_manager): ")

print("\nType 'exit' to stop\n")

while True:

    question = input("You: ")

    if question.lower() == "exit":
        print("Goodbye!")
        break

    prompt = f"""
You are acting as a {role}.

Answer the following question clearly.

Question: {question}
"""

    response = client.responses.create(
        model="gpt-4.1-mini",
        input=prompt
    )

    print("\nAI:", response.output_text)
    print()
# Out:
# AI Role Assistant
#
# Choose role (teacher / programmer / product_manager): programmer
#
# Type 'exit' to stop
#
# You: what is RAG?
#
# AI: RAG stands for **Retrieval-Augmented Generation**.
#
# It is a technique commonly used in natural language processing (NLP) and AI where a language model (like GPT) is combined with an external information retrieval system. Instead of relying solely on its pre-trained knowledge, the model retrieves relevant documents or data from a database or knowledge base and uses that information to generate more accurate, up-to-date, and contextually relevant responses.
#
# ### Key points about RAG:
# - **Retrieval**: The system first searches a large collection of documents or data sources to find relevant pieces of information related to the user’s query.
# - **Augmentation**: The retrieved information is then used as additional input or context for the language model.
# ...

# %%
print("AI Role Assistant\n")

role = input("Choose role (teacher / programmer / product_manager/ ai_architect/ doctor/ Lawyer/ startup_founder): ")

print("\nType 'exit' to stop\n")

while True:

    question = input("You: ")

    if question.lower() == "exit":
        print("Goodbye!")
        break

    prompt = f"""
You are acting as a {role}.

Answer the following question clearly and answer in 3 steps.

Question: {question}
"""

    response = client.responses.create(
        model="gpt-4.1-mini",
        input=prompt
    )

    print("\nAI:", response.output_text)
    print()
# Out:
# AI Role Assistant
#
# Choose role (teacher / programmer / product_manager/ ai_architect/ doctor/ Lawyer/ startup_founder): ai_architect
#
# Type 'exit' to stop
#
# You: What is RAG?
#
# AI: Certainly! Here’s a clear 3-step explanation of RAG:
#
# 1. **Definition**: RAG stands for **Retrieval-Augmented Generation**, a technique in AI that combines retrieval-based methods with generative models to produce more accurate and informed responses.
#
# 2. **How it works**: The system first **retrieves relevant documents or data** from a large external knowledge base based on the input query. Then, a generative model (like a large language model) **uses the retrieved information to generate a contextually grounded and enhanced response**.
#
# ...
